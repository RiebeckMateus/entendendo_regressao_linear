# %%
import requests
import pandas as pd

# %%
api_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImZibmdkeGhrYXVlYW9sbnlzd2duIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NjM4MjQ5MTcsImV4cCI6MjA3OTQwMDkxN30.fm9MKpmmNadMpbPVekIpwyTuyW9cLO9KRyCbJIOQWSM'

# %%
url = 'https://fbngdxhkaueaolnyswgn.supabase.co/rest/v1/doramas'

params = {
    'select': '*'
    # , 'slug': "eq.o-chefe-da-mafia-implora"
}

headers = {
    "apikey": f"{api_key}",
    "authorization": f"Bearer {api_key}",
    "accept": "application/json"
}

# %%
response = requests.get(url, headers=headers, params=params)

response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# [{'id': '896d8611-8b47-43a6-9fbe-b89affe78539',
#   'title': 'Dilemas de um amor Eterno',
#   'slug': 'dilemas-de-um-amor-eterno',
#   'description': 'O amor eterno que prometeram se deparou com tudo que o mundo usa para testar promessas: distância, tempo, orgulho e silêncio. Os dilemas que surgiram não tinham resposta fácil — mas o amor verdadeiro raramente as tem.',
#   'release_year': 2025,
#   'genres': '',
#   'cover_url': 'https://fbngdxhkaueaolnyswgn.supabase.co/storage/v1/object/public/covers/covers/1768159529722-37gitn.jpg',
#   'banner_url': '',
#   'created_at': '2026-01-11T19:25:29.32858+00:00',
#   'video_id': None,
#   'is_exclusive': False,
#   'is_new': True,
#   'language': 'legendado',
#   'is_featured': False,
#   'bunny_url': 'https://doramasplus.b-cdn.net/Dilemas%20de%20um%20amor%20Eterno.mp4',
#   'is_recommended': True,
#   'is_baby_pregnancy': False,
#   'is_taboo_relationship': False,
#   'is_hidden_identity': False,
#   'duration_minutes': 249,
# ...

# %%
df = pd.DataFrame(data)[['slug', 'title', 'description', 'cover_url', 'language', 'bunny_url']]

df
# Out:
#                                                  title  \
# 0                            Dilemas de um amor Eterno
# 1                        Filho do alfa segredo do Amor
# 2                                   Mascarada Vingança
# 3                              Retorno do Desaparecido
# 4                                   O Preço de te Amar
# ..                                                 ...
# 995  A Tutora do Bad Boy/ Tutor dos Bad Boys/ Bad B...
# 996                                     Amor em Cinzas
# 997                                    Amor em Segredo
# 998          Afasta-te ex, Ela é a Rainha Lycan Oculta
# 999                                     Guerra de Vaga
#
#                                            description  \
# 0    O amor eterno que prometeram se deparou com tu...
# 1    O filho do alfa era um segredo guardado por el...
# 2    Por trás da máscara havia uma vingança meticul...
# 3    Ele desapareceu sem deixar rastro. Quando reto...
# ...

# %%
df.fillna('NI', inplace=True)

# %%
df.to_csv(
    path_or_buf='doramas.csv'
    , sep=';'
    , encoding='utf-8'
    , index=False
)
